# %%
import pandas as pd
import numpy as np

# %%
champion = pd.read_csv("dataset/champion.csv")
ranking = pd.read_csv("dataset/fifa_ranking.csv")

# %%
# We will select only CAF federations

ranking  = ranking[ranking["confederation"] == "CAF"]
ranking.head()
# Out:
#     rank   country_full country_abrv  total_points  previous_points  \
# 2   32.0         Zambia          ZAM          38.0              0.0
# 4   30.0        Algeria          ALG          39.0              0.0
# 7   27.0  Côte d'Ivoire          CIV          41.0              0.0
# 12  22.0       Cameroon          CMR          43.0              0.0
# 13  21.0          Egypt          EGY          45.0              0.0
#
#     rank_change confederation   rank_date
# 2            32           CAF  1992-12-31
# 4            30           CAF  1992-12-31
# 7            27           CAF  1992-12-31
# 12           22           CAF  1992-12-31
# 13           21           CAF  1992-12-31

# %%
champion.head()
# Out:
#    year    winner runner-up
# 0  1957     Egypt  Ethiopia
# 1  1959     Egypt     Sudan
# 2  1962  Ethiopia     Egypt
# 3  1963     Ghana     Sudan
# 4  1965     Ghana   Tunisia

# %%
# Reindexing ranking's rows
ranking = ranking.reset_index(drop=True)
ranking.head()
# Out:
#    rank   country_full country_abrv  total_points  previous_points  \
# 0  32.0         Zambia          ZAM          38.0              0.0
# 1  30.0        Algeria          ALG          39.0              0.0
# 2  27.0  Côte d'Ivoire          CIV          41.0              0.0
# 3  22.0       Cameroon          CMR          43.0              0.0
# 4  21.0          Egypt          EGY          45.0              0.0
#
#    rank_change confederation   rank_date
# 0           32           CAF  1992-12-31
# 1           30           CAF  1992-12-31
# 2           27           CAF  1992-12-31
# 3           22           CAF  1992-12-31
# 4           21           CAF  1992-12-31

# %%
ranking = ranking.drop(["country_abrv","total_points","previous_points","rank_change","rank_date","confederation"],axis=1)
ranking.head()
# Out:
#    rank   country_full
# 0  32.0         Zambia
# 1  30.0        Algeria
# 2  27.0  Côte d'Ivoire
# 3  22.0       Cameroon
# 4  21.0          Egypt

# %%
ranking = ranking.rename(columns={"country_full":"Country"})
ranking.head()
# Out:
#    rank        Country
# 0  32.0         Zambia
# 1  30.0        Algeria
# 2  27.0  Côte d'Ivoire
# 3  22.0       Cameroon
# 4  21.0          Egypt

# %%
# Renaming some African countries with their actual names
ranking = ranking.drop_duplicates(subset='Country')
ranking = ranking.reset_index(drop=True)
ranking
# Out:
#      rank                   Country
# 0    32.0                    Zambia
# 1    30.0                   Algeria
# 2    27.0             Côte d'Ivoire
# 3    22.0                  Cameroon
# 4    21.0                     Egypt
# 5    54.0                  Zimbabwe
# 6    53.0                    Malawi
# 7    51.0                   Senegal
# 8    41.0                   Morocco
# 9    39.0                     Ghana
# 10   38.0                   Tunisia
# 11   55.0                     Gabon
# 12   13.0                   Nigeria
# 13  150.0                The Gambia
# 14  151.0         Equatorial Guinea
# 15  155.0                      Chad
# 16  163.0                    Rwanda
# 17  163.0                   Somalia
# 18  158.0                   Namibia
# 19  148.0  Central African Republic
# 20  147.0                Seychelles
# 21  142.0                   Lesotho
# 22  117.0             Guinea-Bissau
# 23  112.0                 Mauritius
# 24  111.0                     Sudan
# 25  107.0                Mozambique
# 26  104.0                  Eswatini
# 27  102.0                    Angola
# 28  137.0                     Libya
# 29  135.0                Cabo Verde
# 30  134.0                Mauritania
# 31  127.0                     Benin
# 32  124.0              South Africa
# 33  101.0                      Togo
# 34  100.0                   Burundi
# 35  139.0                  Botswana
# 36   69.0                      Mali
# 37   76.0                     Kenya
# 38   74.0                Madagascar
# 39   63.0                    Guinea
# 40   60.0                     Zaire
# 41   80.0                  Tanzania
# 42   97.0              Burkina Faso
# 43   79.0              Sierra Leone
# 44   90.0                     Congo
# 45   92.0                    Uganda
# 46   85.0                  Ethiopia
# 47   84.0                   Liberia
# 48   81.0                     Niger
# 49  169.0                  Djibouti
# 50  194.0     Sao Tome and Principe
# 51  189.0                   Eritrea
# 52   59.0                  Congo DR
# 53  207.0                   Comoros
# 54  199.0               South Sudan

# %%
# Dropping Teams who didn't qualify to afcoons

qualified_teams = ["Morocco",
"Burkina Faso",
"Cameroon",
"Algeria",
"DR Congo"
"Senegal",
"Egypt",
"Angola",
"Equatorial Guinea",
"Ivory Coast",
"Uganda"
"South Africa",
"Gabon",
"Tunisia",
"Nigeria",
"Zambia",
"Mali",
"Zimbabwe",
"Comoros",
"Sudan",
"Benin",
"Tanzania",
"Botswana",
"Mozambique"]

replace_name = {
    "Congo DR" : "DR Congo",
    "Zaire" :"DR Congo",
    "Côte d'Ivoire" : "Ivory Coast",
    "Côte d'Ivoire" : "Ivory Coast"
}

ranking["Country"] = ranking["Country"].replace(replace_name)
champion["winner"] = champion["winner"].replace(replace_name)
champion["runner-up"] = champion["runner-up"].replace(replace_name)

# %%
# We will keep just the qualified teams to the Afcoon 
# Source : https://www.cafonline.com/caf-africa-cup-of-nations/news/totalenergies-caf-afcon-2025-24-nations-confirmed-for-morocco-finals/

n = len(ranking)
ranking = ranking[ranking["Country"].isin(qualified_teams)]

# %%
ranking
# Out:
#      rank            Country
# 0    32.0             Zambia
# 1    30.0            Algeria
# 2    27.0        Ivory Coast
# 3    22.0           Cameroon
# 4    21.0              Egypt
# 5    54.0           Zimbabwe
# 8    41.0            Morocco
# 10   38.0            Tunisia
# 11   55.0              Gabon
# 12   13.0            Nigeria
# 14  151.0  Equatorial Guinea
# 24  111.0              Sudan
# 25  107.0         Mozambique
# 27  102.0             Angola
# 31  127.0              Benin
# 35  139.0           Botswana
# 36   69.0               Mali
# 41   80.0           Tanzania
# 42   97.0       Burkina Faso
# 53  207.0            Comoros

# %%
# Let's update their rankings

updated_rankings = {
    "Morocco": 14,
    "Burkina Faso": 67,
    "Cameroon": 51,
    "Algeria": 46,
    "DR Congo": 60,
    "Senegal": 19,
    "Egypt": 36,
    "Angola": 90,
    "Equatorial Guinea": 88,
    "Ivory Coast": 38,
    "Uganda": 92,
    "South Africa": 57,
    "Gabon": 83,
    "Tunisia": 41,
    "Nigeria": 39,
    "Zambia": 92,
    "Mali": 53,
    "Zimbabwe": 125,
    "Comoros": 129,
    "Sudan": 128,
    "Benin": 91,
    "Tanzania": 130,
    "Botswana": 148,
    "Mozambique": 114
}

def fetch_country(rank):
    result = ranking.loc[ranking["rank"] == rank, "Country"]
    return result.iloc[0] if not result.empty else None
    
ranking["rank"] = ranking["rank"].apply(lambda r: updated_rankings.get(fetch_country(r), r))
# Out:
# /tmp/ipykernel_12047/517419925.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking["rank"] = ranking["rank"].apply(lambda r: updated_rankings.get(fetch_country(r), r))

# %%
ranking = ranking.sort_values(by=["rank"],ascending = True)
ranking.reset_index(drop=True)
# Out:
#     rank            Country
# 0     14            Morocco
# 1     36              Egypt
# 2     38        Ivory Coast
# 3     39            Nigeria
# 4     41            Tunisia
# 5     46            Algeria
# 6     51           Cameroon
# 7     53               Mali
# 8     67       Burkina Faso
# 9     83              Gabon
# 10    88  Equatorial Guinea
# 11    90             Angola
# 12    91              Benin
# 13    92             Zambia
# 14   114         Mozambique
# 15   125           Zimbabwe
# 16   128              Sudan
# 17   129            Comoros
# 18   130           Tanzania
# 19   148           Botswana

# %%
stats = pd.read_csv("dataset/stats.csv")
stats = stats.drop(["Rank"],axis=1)
stats.head()
# Out:
#           Team  Part  Pld   W   D   L   GF   GA  GD  Points
# 0        Egypt    26  111  60  24  27  175   97  78     204
# 1      Nigeria    20  104  57  24  23  146   95  50     195
# 2        Ghana    24  105  54  23  28  138   93  45     185
# 3  Ivory Coast    25  106  48  30  28  152  111  41     174
# 4     Cameroon    21   95  46  31  18  142   90  52     169

# %%
stats = stats.rename(columns={"Team":"Country"})
data = ranking.merge(stats,how="inner",on="Country")
data.head()
# Out:
#    rank      Country  Part  Pld   W   D   L   GF   GA  GD  Points
# 0    14      Morocco    19   74  29  25  20   87   65  22     112
# 1    36        Egypt    26  111  60  24  27  175   97  78     204
# 2    38  Ivory Coast    25  106  48  30  28  152  111  41     174
# 3    39      Nigeria    20  104  57  24  23  146   95  50     195
# 4    41      Tunisia    21   83  25  30  27   99   97   2     105

# %%
data.to_csv('dataset/test.csv')
